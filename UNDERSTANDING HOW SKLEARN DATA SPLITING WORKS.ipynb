# %%
#UNDERSTANDING HOW SKLEARN DATA SPLITING WORKS

# %%
#import required library
import pandas as pd #for data processing and reading

# %%
#train
df=pd.read_csv('ausraindata.csv')
#test
test=pd.read_csv('ausraindata.csv')

# %%
y=df["RainTomorrow"]

# %%
#import sklearn library for spliting
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,y_train,y_test=train_test_split(test,y,test_size=0.25)

# %%
#25% OF TEST DATASET
X_test
# Out:
#               Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 39151   2009-12-04    Williamtown     10.6     27.3       0.0          7.4
# 135901  2017-06-05   AliceSprings      2.4     20.4       0.0          NaN
# 28304   2014-03-14       Richmond     16.5     29.2       0.0          3.4
# 34267   2013-03-03  SydneyAirport     16.9     26.1       2.0          4.8
# 134597  2013-11-01   AliceSprings     12.2     33.1       0.0         13.8
# ...            ...            ...      ...      ...       ...          ...
# 6408    2010-04-16          Cobar     11.8     27.6       0.0          4.4
# 123560  2016-09-01     SalmonGums     10.0     15.1       5.4          NaN
# 110980  2014-10-26    Witchcliffe     13.8     19.8       1.8          NaN
# 38941   2009-05-07    Williamtown      8.7     22.3       0.0          2.8
# 24081   2010-05-06        Penrith      4.9     21.4       1.2          NaN
#
# ...

# %%
#75% OF Test_TRAIN or remaining test DATASET
X_train
# Out:
#               Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 698     2010-11-08         Albury     14.7     24.7       2.2          NaN
# 41033   2016-06-30    Williamtown      1.7     16.6       0.0          2.2
# 138148  2014-11-03         Darwin     26.0     35.6       0.0          7.6
# 50417   2016-07-08    Tuggeranong      7.2     11.3       0.0          NaN
# 99829   2017-01-23   MountGambier     18.3     29.8       0.0          NaN
# ...            ...            ...      ...      ...       ...          ...
# 105267  2015-07-16        Woomera      4.7     15.1       0.0          2.2
# 29324   2017-01-03       Richmond     16.6     28.9       0.2          2.2
# 21796   2012-04-24  NorfolkIsland     18.5     22.6       1.2          4.0
# 48502   2010-12-27    Tuggeranong     14.2     25.1       0.6          NaN
# 29733   2008-09-24         Sydney      9.7     18.6       2.2          2.4
#
# ...

# %%
y_train
# Out:
# 698        No
# 41033      No
# 138148     No
# 50417      No
# 99829     Yes
#          ...
# 105267     No
# 29324      No
# 21796      No
# 48502      No
# 29733      No
# Name: RainTomorrow, Length: 106644, dtype: object

# %%
y_test
# Out:
# 39151      No
# 135901     No
# 28304      No
# 34267     Yes
# 134597     No
#          ...
# 6408       No
# 123560     No
# 110980     No
# 38941      No
# 24081      No
# Name: RainTomorrow, Length: 35549, dtype: object

# %%
X_test.shape, X_train.shape, y_test.shape, y_train.shape
# Out:
# ((35549, 24), (106644, 24), (35549,), (106644,))

# %%
id=X_test["Location"]
id
# Out:
# 39151       Williamtown
# 135901     AliceSprings
# 28304          Richmond
# 34267     SydneyAirport
# 134597     AliceSprings
#               ...
# 6408              Cobar
# 123560       SalmonGums
# 110980      Witchcliffe
# 38941       Williamtown
# 24081           Penrith
# Name: Location, Length: 35549, dtype: object

# %%
id.shape
# Out:
# (35549,)

# %%
#to get the number of columns
len(test.columns)
# Out:
# 24

# %%
#to get unique values of a specific column
df['WindGustDir'].unique()
# Out:
# array(['W', 'WNW', 'WSW', 'NE', 'NNW', 'N', 'NNE', 'SW', 'ENE', 'SSE',
#        'S', 'NW', 'SE', 'ESE', nan, 'E', 'SSW'], dtype=object)

# %%
df.Location.value_counts()
# Out:
# Canberra            3418
# Sydney              3337
# Perth               3193
# Darwin              3192
# Hobart              3188
# Brisbane            3161
# Adelaide            3090
# Bendigo             3034
# Townsville          3033
# AliceSprings        3031
# MountGambier        3030
# Ballarat            3028
# Launceston          3028
# Albany              3016
# Albury              3011
# PerthAirport        3009
# MelbourneAirport    3009
# Mildura             3007
# SydneyAirport       3005
# Nuriootpa           3002
# Sale                3000
# Watsonia            2999
# Tuggeranong         2998
# Portland            2996
# Woomera             2990
# Cobar               2988
# Cairns              2988
# Wollongong          2983
# GoldCoast           2980
# WaggaWagga          2976
# Penrith             2964
# NorfolkIsland       2964
# Newcastle           2955
# SalmonGums          2955
# CoffsHarbour        2953
# Witchcliffe         2952
# Richmond            2951
# ...
